# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 37.2
sigma = 4.5
mu = np.arange(x - 10, x + 10, 1)

J = ((x - mu)/sigma)**2

plt.plot(mu, J)
plt.xlabel('$\mu$', fontsize = 14)
plt.ylabel('J($\mu$)', fontsize = 14)
plt.show()
